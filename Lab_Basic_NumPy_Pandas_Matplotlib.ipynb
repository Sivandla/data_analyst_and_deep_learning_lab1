# %% [markdown]
# # **Lab cơ bản về NumPy, Pandas và Matplotlib**

# %% [markdown]
# ### **Giới thiệu**
# Lab này tập trung vào các lệnh cơ bản nhất của **NumPy**, **Pandas**, và **Matplotlib**.
# Bạn sẽ thực hành:
# - Tạo và thao tác với mảng NumPy.
# - Tạo và xử lý dữ liệu trong Pandas DataFrame.
# - Vẽ biểu đồ cơ bản với Matplotlib.

# %% [markdown]
# ## **Phần 1: NumPy**

# %% [markdown]
# ### **1.1: Tạo mảng NumPy**

# %%
import numpy as np

# Tạo một mảng 1D
array_1d = np.array([1, 2, 3, 4, 5])
print("Mảng 1D:", array_1d)

# Tạo một mảng 2D
array_2d = np.array([[1, 2, 3], [4, 5, 6]])
print("Mảng 2D:", array_2d)

# Tạo mảng số ngẫu nhiên
random_array = np.random.rand(3, 3)
print("Mảng số ngẫu nhiên:", random_array)
# Out:
# Mảng 1D: [1 2 3 4 5]
# Mảng 2D: [[1 2 3]
#  [4 5 6]]
# Mảng số ngẫu nhiên: [[0.75000169 0.94600743 0.46296479]
#  [0.48434294 0.58054035 0.52948914]
#  [0.48176656 0.40696452 0.64214293]]

# %% [markdown]
# ### **1.2: Các thao tác cơ bản**

# %%
# Các thao tác cơ bản với mảng
array = np.array([10, 20, 30, 40, 50])

# Cộng, trừ, nhân, chia với một số
print("Cộng thêm 10:", array + 10)
print("Nhân với 2:", array * 2)

# Tính tổng, trung bình, lớn nhất, nhỏ nhất
print("Tổng:", array.sum())
print("Trung bình:", array.mean())
print("Giá trị lớn nhất:", array.max())
print("Giá trị nhỏ nhất:", array.min())

# Lấy phần tử và lát cắt
print("Phần tử đầu tiên:", array[0])
print("Lát cắt [1:4]:", array[1:4])
# Out:
# Cộng thêm 10: [20 30 40 50 60]
# Nhân với 2: [ 20  40  60  80 100]
# Tổng: 150
# Trung bình: 30.0
# Giá trị lớn nhất: 50
# Giá trị nhỏ nhất: 10
# Phần tử đầu tiên: 10
# Lát cắt [1:4]: [20 30 40]

# %% [markdown]
# ## **Phần 2: Pandas**

# %% [markdown]
# ### **2.1: Tạo DataFrame**

# %%
import pandas as pd

# Tạo DataFrame từ dictionary
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "Score": [85, 90, 95]
}
df = pd.DataFrame(data)
print("DataFrame:", df)
# Out:
# DataFrame:       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   35     95

# %% [markdown]
# ### **2.2: Các thao tác cơ bản với DataFrame**

# %%
# Truy cập dữ liệu
print("Cột Age:", df["Age"])
print("Hàng đầu tiên:", df.iloc[0])

# Lọc dữ liệu
filtered_df = df[df["Score"] > 85]
print("Học sinh có điểm > 85:", filtered_df)

# Tính toán
print("Tuổi trung bình:", df["Age"].mean())
# Out:
# Cột Age: 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64
# Hàng đầu tiên: Name     Alice
# Age         25
# Score       85
# Name: 0, dtype: object
# Học sinh có điểm > 85:       Name  Age  Score
# 1      Bob   30     90
# 2  Charlie   35     95
# Tuổi trung bình: 30.0

# %% [markdown]
# ## **Phần 3: Matplotlib**

# %% [markdown]
# ### **3.1: Biểu đồ đường**

# %%
import matplotlib.pyplot as plt

# Vẽ biểu đồ đường
x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

plt.plot(x, y, label="Biểu đồ đường", color="blue", marker="o")
plt.title("Biểu đồ đường cơ bản")
plt.xlabel("Trục X")
plt.ylabel("Trục Y")
plt.legend()
plt.show()

# %% [markdown]
# ### **3.2: Biểu đồ cột**

# %%
# Vẽ biểu đồ cột
categories = ["A", "B", "C", "D"]
values = [5, 7, 3, 8]

plt.bar(categories, values, color="skyblue")
plt.title("Biểu đồ cột")
plt.xlabel("Danh mục")
plt.ylabel("Giá trị")
plt.show()

# %% [markdown]
# ### **3.3: Biểu đồ phân tán**

# %%
# Vẽ biểu đồ phân tán
x = np.random.rand(50)
y = np.random.rand(50)
sizes = np.random.rand(50) * 100

plt.scatter(x, y, s=sizes, alpha=0.5, c='green')
plt.title("Biểu đồ phân tán")
plt.xlabel("Trục X")
plt.ylabel("Trục Y")
plt.show()

# %% [markdown]
# ### Bài tập

# %%
x = [1, 2, 3, 4, 5]
